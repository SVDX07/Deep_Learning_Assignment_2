# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading dogs-vs-cats.zip to /content
#  99% 1.05G/1.06G [00:11<00:00, 87.1MB/s]
# 100% 1.06G/1.06G [00:11<00:00, 95.7MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dogs-vs-cats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16

# %%
conv_base = VGG16(
    weights='imagenet',
    include_top = False,
    input_shape=(150,150,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
from keras.utils import plot_model

plot_model(model)

# %%
conv_base.trainable = False

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
batch_size = 32

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/train',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        '/content/test',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit_generator(
        train_generator,
        epochs=10,
        validation_data=validation_generator)
# Out:
# <ipython-input-11-b2b64d53260b>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/10
# 625/625 [==============================] - 166s 248ms/step - loss: 0.3156 - accuracy: 0.8630 - val_loss: 0.2318 - val_accuracy: 0.9002
# Epoch 2/10
# 625/625 [==============================] - 160s 256ms/step - loss: 0.2407 - accuracy: 0.8964 - val_loss: 0.2015 - val_accuracy: 0.9138
# Epoch 3/10
# 625/625 [==============================] - 157s 251ms/step - loss: 0.2230 - accuracy: 0.9038 - val_loss: 0.2265 - val_accuracy: 0.9038
# Epoch 4/10
# 625/625 [==============================] - 156s 249ms/step - loss: 0.2080 - accuracy: 0.9114 - val_loss: 0.2120 - val_accuracy: 0.9088
# Epoch 5/10
# 625/625 [==============================] - 153s 245ms/step - loss: 0.1983 - accuracy: 0.9151 - val_loss: 0.2062 - val_accuracy: 0.9130
# Epoch 6/10
# 625/625 [==============================] - 153s 245ms/step - loss: 0.1909 - accuracy: 0.9190 - val_loss: 0.2212 - val_accuracy: 0.9090
# Epoch 7/10
# 625/625 [==============================] - 155s 247ms/step - loss: 0.1891 - accuracy: 0.9198 - val_loss: 0.1918 - val_accuracy: 0.9184
# Epoch 8/10
# 625/625 [==============================] - 153s 244ms/step - loss: 0.1765 - accuracy: 0.9245 - val_loss: 0.1970 - val_accuracy: 0.9184
# Epoch 9/10
# 625/625 [==============================] - 153s 245ms/step - loss: 0.1683 - accuracy: 0.9298 - val_loss: 0.1945 - val_accuracy: 0.9154
# Epoch 10/10
# 625/625 [==============================] - 153s 245ms/step - loss: 0.1641 - accuracy: 0.9305 - val_loss: 0.1915 - val_accuracy: 0.9180

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()
